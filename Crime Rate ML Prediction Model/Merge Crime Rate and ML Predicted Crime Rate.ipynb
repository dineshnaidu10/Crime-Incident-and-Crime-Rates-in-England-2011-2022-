# %%
import pandas as pd

# %%
df = pd.read_csv('2011-2022_mergedcrimerate.csv')
df_xg = pd.read_csv('xgboost_prediction.csv')
df_rf = pd.read_csv('rf_prediction.csv')

# %%
df = pd.concat([df, df_xg, df_rf], axis=1)

# %%
df.to_csv('2011-2022_mergedcrimerate.csv', index=False)

# %%
df.head()
# Out:
#      Month  LSOA code  Count  Population  Pop_density  IMD Score  \
# 0  2011-01  E01007599      1      1760.0      15.6031      11.20
# 1  2011-01  E01007609      2      2302.0      17.9576      18.22
# 2  2011-01  E01013810      6      1657.0       0.1345      39.59
# 3  2011-01  E01013811     26      1446.0       0.1280      45.17
# 4  2011-01  E01013812     19      1617.0       0.1209      47.45
#
#    Income Score  IDACI Score  IDAOPI Score  Employment Score  ...  GB Score  \
# 0          0.07         0.07          0.13              0.06  ...     55.81
# 1          0.13         0.13          0.22              0.10  ...     21.48
# 2          0.29         0.42          0.44              0.13  ...      1.25
# 3          0.27         0.41          0.58              0.16  ...      0.22
# 4          0.36         0.55          0.45              0.16  ...      0.17
#
#    WB Score  LE Score  Indoors Score  Outdoors Score  Inflation_rate  \
# ...
